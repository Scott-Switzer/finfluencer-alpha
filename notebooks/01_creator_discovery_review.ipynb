# %% [markdown]
# # Creator Discovery Review
#
# Use this notebook to inspect `data/exports/x_creator_candidates.csv`, `data/exports/youtube_creator_candidates.csv`, and `data/exports/recommendation_candidates.csv` after running the MVP pipeline.

# %%
import pandas as pd
from pathlib import Path

exports = Path('../data/exports')
x = pd.read_csv(exports / 'x_creator_candidates.csv') if (exports / 'x_creator_candidates.csv').exists() else pd.DataFrame()
youtube = pd.read_csv(exports / 'youtube_creator_candidates.csv') if (exports / 'youtube_creator_candidates.csv').exists() else pd.DataFrame()
recs = pd.read_csv(exports / 'recommendation_candidates.csv') if (exports / 'recommendation_candidates.csv').exists() else pd.DataFrame()
x.head(), youtube.head(), recs.head()
